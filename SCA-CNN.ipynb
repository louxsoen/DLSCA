# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

# %%
defPt    = np.load(r'/Users/louxsoen/Documents/Univ/부채널연구/Traces/AES/trace_20000/2022.03.25-06.05.29_textin.npy')
defTrace = np.load(r'/Users/louxsoen/Documents/Univ/부채널연구/Traces/AES/trace_20000/2022.03.25-06.05.29_traces.npy')
#atkPt    = np.load(r'/Users/louxsoen/Documents/Univ/부채널연구/Traces/AES/trace_10000/2022.03.25-05.40.47_textin.npy')
#atkTrace = np.load(r'/Users/louxsoen/Documents/Univ/부채널연구/Traces/AES/trace_10000/2022.03.25-05.40.47_traces.npy')

# %%
sbox = (
     )
MK = ( 0x01, 0x23, 0x45, 0x67, 0x89, 0xab, 0xcd, 0xef, 0x12, 0x34, 0x56, 0x78, 0x9a, 0xbc, 0xde, 0xf0 )

myLen = 3000
myNum = 20000

iv = np.zeros((myNum))
for i in range(myLen):
    iv[i] = bin(sbox[defPt[i][0] ^ MK[0]]).count('1')

trace = defTrace[:myNum,:myLen]
x_train, x_test = train_test_split(trace, test_size = 0.3, shuffle = False)
y_train, y_test = train_test_split(iv , test_size = 0.3, shuffle = False)

#x_val, y_val = train_test_split(at , test_size = 0.4, shuffle = False)

# %%
print("x train |", x_train.shape)
print("x test  |", x_test.shape)
print("y train |", y_train.shape)
print("y test  |", y_test.shape)

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
y_train = np.expand_dims(y_train, -1)
y_test = np.expand_dims(y_test, -1)

#x_val = np.expand_dims(x_val, -1)
#y_val = np.expand_dims(y_val, -1)
print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
print(y_test.shape)

#print(x_val.shape)

plt.plot(trace[0])
plt.show()
plt.plot(iv)
plt.show()
# Out:
# x train | (14000, 3000)
# x test  | (6000, 3000)
# y train | (14000,)
# y test  | (6000,)
# (14000, 3000, 1)
# (6000, 3000, 1)
# (14000, 1)
# (6000, 1)

# %% [markdown]
# <h1>제발 이거 CNN이니까 MLP, DNN처럼 날려먹지마 제발제발젭알젭알젭랑ㄹ </h1>
# <b>한번 더 날리면 손목 잘라라 </b>

# %%
model = tf.keras.Sequential([
    
    tf.keras.Input(shape=(x_train.shape[1], 1)),
    
    tf.keras.layers.Conv1D(256, kernel_size = 3, activation="relu"),
    tf.keras.layers.MaxPooling1D(2),
    
    tf.keras.layers.Conv1D(128, kernel_size = 3, activation="relu"),
    tf.keras.layers.MaxPooling1D(2),
        
    tf.keras.layers.Conv1D(64, kernel_size = 3, activation="relu"),
    tf.keras.layers.MaxPooling1D(2),
        
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16, activation="relu"),
    tf.keras.layers.Dense(9, activation="softmax"),
    ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2998, 256)         1024
#
#  max_pooling1d (MaxPooling1D  (None, 1499, 256)        0
#  )
#
#  conv1d_1 (Conv1D)           (None, 1497, 128)         98432
#
#  max_pooling1d_1 (MaxPooling  (None, 748, 128)         0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 746, 64)           24640
#
#  max_pooling1d_2 (MaxPooling  (None, 373, 64)          0
#  1D)
#
#  flatten (Flatten)           (None, 23872)             0
#
#  dense (Dense)               (None, 16)                381968
#
#  dense_1 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 506,217
# Trainable params: 506,217
# Non-trainable params: 0
# _________________________________________________________________
# 2022-04-01 12:36:17.606361: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(
    optimizer = "adam",
    loss = "sparse_categorical_crossentropy",
    metrics =["accuracy"]
)

history = model.fit(x_train, y_train, epochs = 15, validation_split = (0.3), batch_size = 64)
# Out:
# Epoch 1/15
# 154/154 [==============================] - 112s 723ms/step - loss: 1.2202 - accuracy: 0.6897 - val_loss: 0.3987 - val_accuracy: 1.0000
# Epoch 2/15
# 154/154 [==============================] - 120s 779ms/step - loss: 1.1540 - accuracy: 0.6949 - val_loss: 0.4186 - val_accuracy: 1.0000
# Epoch 3/15
# 154/154 [==============================] - 116s 756ms/step - loss: 1.1493 - accuracy: 0.6949 - val_loss: 0.4155 - val_accuracy: 1.0000
# Epoch 4/15
# 154/154 [==============================] - 120s 782ms/step - loss: 1.1474 - accuracy: 0.6949 - val_loss: 0.3296 - val_accuracy: 1.0000
# Epoch 5/15
#  88/154 [================>.............] - ETA: 45s - loss: 1.1610 - accuracy: 0.6909

# %%
output_test_result = model.evaluate(x_test, y_test, verbose=0)
print('test model |      Loss :', output_test_result[0])
print('           | Accuaracy :', output_test_result[1])

# %%
plt.plot(history.history['accuracy'])
plt.show()

plt.plot(history.history['loss'])
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

predictions = model.predict(x_test)
print("x_test ", np.argmax(predictions[:9], axis = 1))
print("y_test ", y_test)
